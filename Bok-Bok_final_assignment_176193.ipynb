# %% [markdown]
# # Books Exchange Platform Simulation

# %%
pip install names
# Out:
# Requirement already satisfied: names in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.3.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests) (2024.8.30)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import random # The program will be using many randomized variables
import names # To extract the user's names
import requests # To handle the API connection

# %% [markdown]
# ## Book class

# %%
class Book():

    offered_books = [] # List with all the books in the platform (owned by users)

    def __init__(self, title, author, publisher, description, published_date, pages, isbn):
        # Each book will have these attributes
        self.title = title 
        self.author = author 
        self.publisher = publisher
        self.description = description
        self.published_date = published_date
        self.pages = pages
        self.isbn = isbn # Unique for each title

    # Let's populate the platform's offer with books from the Google Books API
    def get_classics(books_to_generate):
        api_key = "AIzaSyDUBRTu6VcZ0V59N0boQMVG7rBmJSkedjA" # Personal key to access the API
        max_books = 960 # We don't want more than 960 books in the platform (1,000 is the daily free quota of the API)
        books_per_request = 40 # The API can only handle 40 requests at a time
        base_url = "https://www.googleapis.com/books/v1/volumes" 
        search_term = "classics" # Let's simulate with classics since in this category there are many of the most famous books

        # If the simulation is ran with less than 40 books
        if books_to_generate <= books_per_request: 
            params = {
                "q": search_term, # Searches only for books labeled as "classics"
                "key": api_key, # Uses my personal API key
                "startIndex": 0, # Starting the book fetching from the first book in the API
                "maxResults": books_to_generate, # Indicates the number of books to request
            }

            try: 
                response = requests.get(base_url, params = params) # Fetches the data from the API using our parameters
                response.raise_for_status() # Checks for HTTP errors in the request
            except requests.exceptions.RequestException as e:
                print(f"Request failed: {e}") # Let the program handle potential errors such as API free quota limit exceeded

            books = response.json() # The API answers the request in JSON format
            if "items" in books: # Checks if the response from the API is consistent
                for item in books["items"]: 
                    # Let's extract the informations from every book
                    volume_info = item.get("volumeInfo", {}) # Necessary because the features we're looking for are inside a nested dictionary
                    title = volume_info.get("title")
                    author = ", ".join(volume_info.get("authors", ["Unknown"])) # Since in the JSON the authors are in a list
                    publisher = volume_info.get("publisher", "Unknown")
                    description = volume_info.get("description", "Description not available")
                    published_date = volume_info.get("publishedDate", "Unknown")
                    pages = volume_info.get("pageCount", "Unknown")
                    industry_identifiers = volume_info.get("industryIdentifiers", []) # The ISBN code is in a further nested dictionary
                    isbn = "Unknown" # Standard value for ISBN
                    for identifier in industry_identifiers:
                        if identifier.get("type") == "ISBN_10":
                            isbn = identifier.get("identifier") # If the book has a ISBN then assign it to him
                            break

                    # Let offered_books collect all the books we collected via the API
                    Book.offered_books.append(Book(title, author, publisher, description, published_date, pages, isbn)) 

            return Book.offered_books
        
        # If the simulation is ran with more than 40 books
        else:
            for start in range(0, books_to_generate, books_per_request): # We have to build this for loop because the API can only handle 40 requests at a time
                params = {
                    "q": search_term, 
                    "key": api_key, 
                    "startIndex": start, # Starts from the end-point of the previous iteration (start)
                    "maxResults": books_per_request, # Will be 40
                }

                try: 
                    response = requests.get(base_url, params = params)
                    response.raise_for_status() 
                except requests.exceptions.RequestException as e:
                    print(f"Request failed: {e}")
                    break

                books = response.json() 
                if "items" in books:
                    for item in books["items"]: 
                        # Let's extract the informations from every book
                        volume_info = item.get("volumeInfo", {}) 
                        title = volume_info.get("title")
                        author = ", ".join(volume_info.get("authors", ["Unknown"]))
                        publisher = volume_info.get("publisher", "Unknown")
                        description = volume_info.get("description", "Description not available")
                        published_date = volume_info.get("publishedDate", "Unknown")
                        pages = volume_info.get("pageCount", "Unknown")
                        industry_identifiers = volume_info.get("industryIdentifiers", []) 
                        isbn = "Unknown" 
                        for identifier in industry_identifiers:
                            if identifier.get("type") == "ISBN_10":
                                isbn = identifier.get("identifier") 
                                break

                        # Let offered_books collect all the books we transferred via the API
                        Book.offered_books.append(Book(title, author, publisher, description, published_date, pages, isbn)) 
                        
                        if len(Book.offered_books) >= max_books: 
                            break
                        
            return Book.offered_books

# %% [markdown]
# ## User class

# %%
class User():

    all_users = [] # Contains every user on the platform
    user_count = 0 # Initialize the counter (useful to assign user_IDs)

    def __init__(self):
        # Each user will have these attributes
        self.name = names.get_full_name() # A string with name and last name
        self.email = self.name.lower().replace(" ", ".") + random.choice(["@gmail.com", "@hotmail.com", "@yahoo.com", "@outlook.com", "@icloud.com"])
        
        max_owned = min(len(Book.offered_books), 30) # A user can offer maximum 30 books on the platform at the same time
        self.owned_books = random.sample(Book.offered_books, random.randint(1, max_owned))
        wishlist_candidates = list(set(Book.offered_books) - set(self.owned_books)) # Avoids that a user's owned book is in his/her wishlist too
        max_wishlist = min(len(wishlist_candidates), 50) # A user's wishlist can contain maximum 50 books
        try:
            self.wishlist = random.sample(wishlist_candidates, random.randint(0, max_wishlist))
        except Exception:
            self.wishlist = [] # Empty wishlist if there are no candidates

        User.user_count += 1
        self.user_id = User.user_count # First user will have user_id = #1 and so on
        User.all_users.append(self) # Adding the new user to the list

        self.exchanges_completed = 0 # Counts how many exchanges a user has completed
    
    def will_exchange(self):
        if random.choice([0, 1, 1]) == 1: 
            return True # The user will exchange (67% probability)
        return False # The user won't exchange (33% probability)

# %% [markdown]
# ## Exchange class

# %%
class Exchange():
    
    exchanges_count = 0 

    # Initializing some counters for the metrics
    rejected_exchanges = 0 
    both_in_wishlists = 0
    one_in_wishlist = 0
    none_in_wishlist = 0
    exchanges_with_balancing = 0 
    card_counter = 0
    paypal_counter = 0
    applepay_counter = 0
    googlepay_counter = 0
    samsungpay_counter = 0
    cash_counter = 0

    def __init__(self):
        self.user1 = random.choice(User.all_users)
        self.user2 = random.choice([user for user in User.all_users if user != self.user1]) # User1 has to be different from User2 ofc
        self.book1 = None # Book the user1 gives to user2 
        self.book2 = None # Book the user2 gives to user1
        self.balancing = random.choice([0, 0, round(random.uniform(2, 10), 2)]) # A book can be exchanged for another book + some money (min 2€ max 10€)
        self.payment_method = random.choice(["Card", "PayPal", "PayPal", "ApplePay", "GooglePay", "SamsungPay", "Cash", "Cash"]) if self.balancing != 0 else None

    # Select the books exchanged and update user's infos
    def perform_exchange(self):

        common_books1 = set(self.user1.owned_books) & set(self.user2.wishlist) # Finds the books that are owned by user1 and wanted by user2
        common_books2 = set(self.user1.wishlist) & set(self.user2.owned_books) # Finds the books that are owned by user2 and wanted by user1
        if self.user1.will_exchange() and self.user2.will_exchange(): # If both the users want to exchange books
            if common_books1 and common_books2: # If the two users have books that are on each other's wishlist
                self.book1 = random.choice(list(common_books1))
                self.book2 = random.choice(list(common_books2))
                self.context = "Both books were on each other's wishlists."
                Exchange.both_in_wishlists += 1
            elif common_books1 and not common_books2: # If user1 has a book that is on user2's wishlist
                self.book1 = random.choice(list(common_books1))
                self.book2 = random.choice(self.user2.owned_books)
                self.context = f"Only '{self.book1.title}' was on {self.user2.name}'s wishlist."
                Exchange.one_in_wishlist += 1
            elif common_books2 and not common_books1: # If user2 has a book that is on user1's wishlist
                self.book1 = random.choice(self.user1.owned_books)
                self.book2 = random.choice(list(common_books2))
                self.context = f"Only '{self.book2.title}' was on {self.user1.name}'s wishlist."
                Exchange.one_in_wishlist += 1
            else: # If the users don't have any book that is on each other's wishlist, but they still want to exchange
                self.book1 = random.choice(self.user1.owned_books)
                self.book2 = random.choice(self.user2.owned_books)
                self.context = "The books were not on each other's wishlists."
                Exchange.none_in_wishlist += 1
            
            # Updating owned_books and wishlist of the users involved in the exchange
            if self.book1 != self.book2: # Avoids to process an exchange of the same book
                self.user1.exchanges_completed += 1 # Updating user1 counter
                self.user2.exchanges_completed += 1 # Updating user2 counter
                self.user1.owned_books.remove(self.book1)
                self.user2.owned_books.remove(self.book2)
                self.user1.owned_books.append(self.book2)
                self.user2.owned_books.append(self.book1)
                if self.book1 in self.user2.wishlist:
                    self.user2.wishlist.remove(self.book1)
                elif self.book2 in self.user1.wishlist:
                    self.user1.wishlist.remove(self.book2)
            
            # Updating the payment method metrics
            if self.balancing > 0:  
                if self.payment_method == "Card":
                    Exchange.card_counter += 1
                elif self.payment_method == "PayPal":
                    Exchange.paypal_counter += 1
                elif self.payment_method == "ApplePay":
                    Exchange.applepay_counter += 1
                elif self.payment_method == "GooglePay":
                    Exchange.googlepay_counter += 1
                elif self.payment_method == "SamsungPay":
                    Exchange.samsungpay_counter += 1
                elif self.payment_method == "Cash":
                    Exchange.cash_counter += 1

        # Scenarios in which the exchange won't happen because rejected by one of the users
        elif self.user1.will_exchange() == False and self.user2.will_exchange(): # User1 rejects
            Exchange.rejected_exchanges += 1
            print(
            f"{self.user1.name} (ID: #{self.user1.user_id}) rejected an exchange with {self.user2.name} (ID: #{self.user2.user_id})."
            )
        elif self.user2.will_exchange() == False and self.user1.will_exchange(): # User2 rejects
            Exchange.rejected_exchanges += 1
            print(
            f"{self.user2.name} (ID: #{self.user2.user_id}) rejected an exchange with {self.user1.name} (ID: #{self.user1.user_id})."
            )

    # Building the output
    def display_exchange(self):
        
        if self.book1 and self.book2: 
            if self.book1 != self.book2: # The exchange can take place
                Exchange.exchanges_count += 1
                self.exchange_id = Exchange.exchanges_count # First exchange will have exchange_id = #1 and so on 
                if self.balancing == 0: # Output for the exchanges without a monetary transaction
                    # Output
                    print (
                    f"\n       ----------------------------------------- Exchange #{self.exchange_id} ----------------------------------------     \n"
                    f"{self.user1.name} (ID: #{self.user1.user_id}) received '{self.book2.title}' from {self.user2.name} (ID: #{self.user2.user_id})\n"
                    f"{self.user2.name} (ID: #{self.user2.user_id}) received '{self.book1.title}' from {self.user1.name} (ID: #{self.user1.user_id})\n"
                    f"No money involved in the transaction.\n"
                    f"{self.context}\n\n"
                    f"INFO: '{self.book1.title}':\n" 
                    f"Author(s): {self.book1.author}, Publisher: {self.book1.publisher}, Date: {self.book1.published_date}, ISBN: {self.book1.isbn}.\n\n"
                    f"INFO: '{self.book2.title}':\n"
                    f"Author(s): {self.book2.author}, Publisher: {self.book2.publisher}, Date: {self.book2.published_date}, ISBN: {self.book2.isbn}.\n"
                    "       ----------------------------------------------------------------------------------------------       \n"
                    )    
                else: # Output for the exchanges with a monetary transaction
                    Exchange.exchanges_with_balancing += 1 # Keeps count of the number of this type of exchanges 
                    user_paying = random.choice([self.user1.name, self.user2.name])
                    user_receiving = self.user1.name if user_paying == self.user2.name else self.user2.name
                    # Output
                    print (
                    f"\n       ----------------------------------------- Exchange #{self.exchange_id} ----------------------------------------     \n"
                    f"{self.user1.name} (ID: #{self.user1.user_id}) received '{self.book2.title}' from {self.user2.name} (ID: #{self.user2.user_id})\n"
                    f"{self.user2.name} (ID: #{self.user2.user_id}) received '{self.book1.title}' from {self.user1.name} (ID: #{self.user1.user_id})\n"
                    f"Money (in €) involved in the transaction: {self.balancing} from {user_paying} to {user_receiving} (Payment Method: {self.payment_method})\n"
                    f"{self.context}\n\n"
                    f"INFO: '{self.book1.title}':\n" 
                    f"Author(s): {self.book1.author}, Publisher: {self.book1.publisher}, Date: {self.book1.published_date}, ISBN: {self.book1.isbn}.\n\n"
                    f"INFO: '{self.book2.title}':\n"
                    f"Author(s): {self.book2.author}, Publisher: {self.book2.publisher}, Date: {self.book2.published_date}, ISBN: {self.book2.isbn}.\n"
                    "       ----------------------------------------------------------------------------------------------       \n"
                    )

# %% [markdown]
# ## Simulation

# %%
# Building the final simulation() function
def simulation(n_users, n_books, n_exchanges): 

    books_fetched = Book.get_classics(n_books) # Fetches books from the API using the get_classics method (can't be more than 1,000)
    try: 
        if not books_fetched:
            raise ValueError (f"Error: the API couldn't fetch any book.")
    except ValueError as e:
        print(f"{e}") # Handles the scenario in which the API can't fetch any book (ex. if n_books = 0)
        return

    users = [User() for i in range(n_users)] # Create n_users istances of users
    try:
        if len(users) < 2 or len(Book.offered_books) < 2:
            raise ValueError(f"Error: not enough books or users to assign owned_books and wishlist, please generate more books or users.\n")
    except ValueError as e:
            print(f"{e}") # Handles the scenario in which there is not a sufficient number of books or users (< 2) to generate an exchange (ex. if n_users = 1)
            return

    try:
        if n_exchanges <= 0:
            raise ValueError (f"Error: the simulation can't run without exchanges.")
    except ValueError as e:
        print(f"{e}") # Handles the scenario in which the user doesn't input a valid number of exchanges
        return

    books = books_fetched[:min(960, n_books)]

    if n_books > 960: # If the user inputs more than 970 books the program proceeeds to run the simulation with the books it managed to fetch from the API
        print(f"WARNING: You cannot generate {n_books} books. Proceeding the simulation with {len(books)} books.\n")
        
    print(f"Books generated (fetched): {len(books)} ({len(books_fetched)})\nUsers generated: {len(users)}\n")

    # Simulation stops when the desired number of completed exchanges is reached
    while Exchange.exchanges_count < n_exchanges: 
        exchanges = [Exchange()] # Creating instances of exchanges
        for exchange in exchanges:
            exchange.perform_exchange() # Perform the exchange
            exchange.display_exchange() # Display the exchange

    # Metrics (displayed only if 10 or more exchanges were completed)
    if Exchange.exchanges_count >= 10: 
        sum_books = 0
        sum_books_wishlist = 0
        inactive_users = 0
        for user in users:
            sum_books += len(user.owned_books)
            sum_books_wishlist += len(user.wishlist)
            if user.exchanges_completed == 0:
                inactive_users += 1
        percentage_inactive_users = round((inactive_users / len(users)) * 100, 2)
        avg_nbooks_per_user = round(sum_books / n_users, 2) # Average of books possessed by a user
        avg_books_wishlist_per_user = round(sum_books_wishlist / n_users, 2) # Average of books in a user's wishlist
        exchanges_completed = Exchange.both_in_wishlists + Exchange.one_in_wishlist + Exchange.none_in_wishlist
        percentage_both_in_wishlist = round((Exchange.both_in_wishlists / exchanges_completed) * 100, 2) # Both the books exchanged were on the users' wishlists
        percentage_one_in_wishlist = round((Exchange.one_in_wishlist / exchanges_completed) * 100, 2) # Only one book exchanged was on a user's wishlist
        percentage_none_in_wishlist = round((Exchange.none_in_wishlist / exchanges_completed) * 100, 2) # The exchanged books were not on the user's wishlist
        percentage_exchanges_with_balancing = round((Exchange.exchanges_with_balancing / exchanges_completed) * 100, 2)
        percentage_card = round((Exchange.card_counter / Exchange.exchanges_with_balancing) * 100, 2)
        percentage_paypal = round((Exchange.paypal_counter / Exchange.exchanges_with_balancing) * 100, 2)
        percentage_applepay = round((Exchange.applepay_counter / Exchange.exchanges_with_balancing) * 100, 2)
        percentage_googlepay = round((Exchange.googlepay_counter / Exchange.exchanges_with_balancing) * 100, 2)
        percentage_samsungpay = round((Exchange.samsungpay_counter / Exchange.exchanges_with_balancing) * 100, 2)
        percentage_cash = round((Exchange.cash_counter / Exchange.exchanges_with_balancing) * 100, 2)

        print("Simulation completed!")
        print("\n       ------------------------------------------ Metrics -------------------------------------------     \n")  
        print(f"Users not involved in any exchange: {inactive_users} ({percentage_inactive_users}%)")
        print(f"Rejected exchanges: {Exchange.rejected_exchanges}")
        print(f"Average number of owned books per user: {avg_nbooks_per_user}")
        print(f"Average number of books in the wishlist per user: {avg_books_wishlist_per_user}")
        print(f"Exchanges involving two books in each other's wishlist: {Exchange.both_in_wishlists} ({percentage_both_in_wishlist}%)")
        print(f"Exchanges in which one book was on a user's wishlist while the other not: {Exchange.one_in_wishlist} ({percentage_one_in_wishlist}%)")
        print(f"Exchanges in which none of the books is on each other's wishlists: {Exchange.none_in_wishlist} ({percentage_none_in_wishlist}%)")
        print(f"Exchanges involving a monetary transaction: {Exchange.exchanges_with_balancing} ({percentage_exchanges_with_balancing}%)")
        print(f"- Card: {Exchange.card_counter} ({percentage_card}%)")
        print(f"- PayPal: {Exchange.paypal_counter} ({percentage_paypal}%)")
        print(f"- ApplePay: {Exchange.applepay_counter} ({percentage_applepay}%)")
        print(f"- GooglePay: {Exchange.googlepay_counter} ({percentage_googlepay}%)")
        print(f"- SamsungPay: {Exchange.samsungpay_counter} ({percentage_samsungpay}%)")
        print(f"- Cash: {Exchange.cash_counter} ({percentage_cash}%)")

# %%
# Asking the user for inputs
def get_inputs_and_run():
    try:
        input_users = int(input("Insert the number of users you wish to generate."))
        input_books = int(input("Insert the number of books you wish to generate. Remember: the API daily free quota is 1000."))
        input_exchanges = int(input("Insert the number of exchanges you wish to generate."))
        return input_users, input_books, input_exchanges
    except ValueError:
        print(f"These inputs must be integers. Try again.")    
        return

# Finally we call the simulation() function
inputs = get_inputs_and_run()
if inputs:
    print(f"Inputs: {inputs[0]} users, {inputs[1]} books, {inputs[2]} exchanges.")
    simulation(inputs[0], inputs[1], inputs[2])
else:
    print("Cannot proceed due to invalid inputs.")
# Out:
# Inputs: 300 users, 343 books, 271 exchanges.
# Books generated (fetched): 343 (360)
# Users generated: 300
#
#
#        ----------------------------------------- Exchange #1 ----------------------------------------
# Michelle King (ID: #197) received 'Manga Classics: Othello Full Original Text' from Eugene Little (ID: #96)
# Eugene Little (ID: #96) received 'Parliamentary Papers' from Michelle King (ID: #197)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Parliamentary Papers':
# Author(s): Great Britain. Parliament. House of Commons, Publisher: Unknown, Date: 1870, ISBN: Unknown.
#
# INFO: 'Manga Classics: Othello Full Original Text':
# Author(s): William Shakespeare, Crystal Chan, Publisher: Manga Classics, Date: Unknown, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #2 ----------------------------------------
# Larry Ward (ID: #185) received 'The American Catalogue ... July 1, 1876-Dec. 31, 1910' from Karen Pagan (ID: #91)
# Karen Pagan (ID: #91) received 'Camus. Conferenze e discorsi (1937-1958)' from Larry Ward (ID: #185)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Camus. Conferenze e discorsi (1937-1958)':
# Author(s): Albert Camus, Publisher: Bompiani, Date: 2020-09-16, ISBN: 8858790693.
#
# INFO: 'The American Catalogue ... July 1, 1876-Dec. 31, 1910':
# Author(s): Unknown, Publisher: Unknown, Date: 1941, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #3 ----------------------------------------
# Steven Degroat (ID: #235) received 'Register ...' from Darnell Lash (ID: #108)
# Darnell Lash (ID: #108) received 'Marriner and the Academy' from Steven Degroat (ID: #235)
# No money involved in the transaction.
# Only 'Marriner and the Academy' was on Darnell Lash's wishlist.
#
# INFO: 'Marriner and the Academy':
# Author(s): Philip Stuart, Publisher: Academy of St. Martin in Fields, Date: 1999, ISBN: Unknown.
#
# INFO: 'Register ...':
# Author(s): University of California, Berkeley, Publisher: Unknown, Date: 1953, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Donna Freeman (ID: #180) rejected an exchange with Kevin Motta (ID: #140).
#
#        ----------------------------------------- Exchange #4 ----------------------------------------
# Violet Bartlett (ID: #27) received 'Encyclopedia of Comic Books and Graphic Novels [2 volumes]' from Denise Palmore (ID: #267)
# Denise Palmore (ID: #267) received 'Academic Evaluation' from Violet Bartlett (ID: #27)
# No money involved in the transaction.
# Only 'Academic Evaluation' was on Denise Palmore's wishlist.
#
# INFO: 'Academic Evaluation':
# Author(s): K. Hyland, G. Diani, Publisher: Springer, Date: 2009-08-12, ISBN: 0230244297.
#
# INFO: 'Encyclopedia of Comic Books and Graphic Novels [2 volumes]':
# Author(s): M. Keith Booker, Publisher: Bloomsbury Publishing USA, Date: 2010-05-11, ISBN: 0313357471.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #5 ----------------------------------------
# Violet Bartlett (ID: #27) received 'The American Catalogue ... July 1, 1876-Dec. 31, 1910' from Donna Freeman (ID: #180)
# Donna Freeman (ID: #180) received 'Traditional Korea' from Violet Bartlett (ID: #27)
# Money (in €) involved in the transaction: 7.38 from Violet Bartlett to Donna Freeman (Payment Method: GooglePay)
# Only 'The American Catalogue ... July 1, 1876-Dec. 31, 1910' was on Violet Bartlett's wishlist.
#
# INFO: 'Traditional Korea':
# Author(s): Wan-je Cho, Publisher: Weatherhill, Date: 1997, ISBN: Unknown.
#
# INFO: 'The American Catalogue ... July 1, 1876-Dec. 31, 1910':
# Author(s): Unknown, Publisher: Unknown, Date: 1941, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #6 ----------------------------------------
# Willie Potts (ID: #41) received 'Under Confucian Eyes' from Mary Shrader (ID: #278)
# Mary Shrader (ID: #278) received 'The Southern Quarterly' from Willie Potts (ID: #41)
# Money (in €) involved in the transaction: 5.27 from Mary Shrader to Willie Potts (Payment Method: GooglePay)
# Only 'The Southern Quarterly' was on Mary Shrader's wishlist.
#
# INFO: 'The Southern Quarterly':
# Author(s): Unknown, Publisher: Unknown, Date: 1982, ISBN: Unknown.
#
# INFO: 'Under Confucian Eyes':
# Author(s): Susan Mann, Yu-Yin Cheng, Publisher: Unknown, Date: 2001, ISBN: 0520222741.
#        ----------------------------------------------------------------------------------------------
#
# Stephanie Richardson (ID: #258) rejected an exchange with Kristina Neal (ID: #69).
# Ruby Evans (ID: #208) rejected an exchange with Latasha Lindsey (ID: #220).
#
#        ----------------------------------------- Exchange #7 ----------------------------------------
# John Elliott (ID: #261) received 'New York Times Saturday Book Review Supplement' from Heidi Grimes (ID: #11)
# Heidi Grimes (ID: #11) received 'The East and the West' from John Elliott (ID: #261)
# No money involved in the transaction.
# Only 'New York Times Saturday Book Review Supplement' was on John Elliott's wishlist.
#
# INFO: 'The East and the West':
# Author(s): Unknown, Publisher: Unknown, Date: 1909, ISBN: Unknown.
#
# INFO: 'New York Times Saturday Book Review Supplement':
# Author(s): Unknown, Publisher: Unknown, Date: 1962-05, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #8 ----------------------------------------
# Juanita Williamson (ID: #116) received 'WALNECK'S CLASSIC CYCLE TRADER, AUGUST 2000' from Beverly Christensen (ID: #276)
# Beverly Christensen (ID: #276) received 'The East and the West' from Juanita Williamson (ID: #116)
# No money involved in the transaction.
# Only 'WALNECK'S CLASSIC CYCLE TRADER, AUGUST 2000' was on Juanita Williamson's wishlist.
#
# INFO: 'The East and the West':
# Author(s): Unknown, Publisher: Unknown, Date: 1909, ISBN: Unknown.
#
# INFO: 'WALNECK'S CLASSIC CYCLE TRADER, AUGUST 2000':
# Author(s): Causey Enterprises, LLC, Publisher: Causey Enterprises, LLC, Date: Unknown, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #9 ----------------------------------------
# Deidre Gregory (ID: #20) received 'Agur's Prayer' from Ronald Wynne (ID: #48)
# Ronald Wynne (ID: #48) received 'Popular Science' from Deidre Gregory (ID: #20)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Popular Science':
# Author(s): Unknown, Publisher: Unknown, Date: 1940-08, ISBN: Unknown.
#
# INFO: 'Agur's Prayer':
# Author(s): Unknown, Publisher: Unknown, Date: 1867, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #10 ----------------------------------------
# Perry Escobedo (ID: #187) received 'Proceedings' from William Burgess (ID: #119)
# William Burgess (ID: #119) received '... Catalogue' from Perry Escobedo (ID: #187)
# No money involved in the transaction.
# Only '... Catalogue' was on William Burgess's wishlist.
#
# INFO: '... Catalogue':
# Author(s): Haverford College, Publisher: Unknown, Date: 1964, ISBN: Unknown.
#
# INFO: 'Proceedings':
# Author(s): Classical Association (Great Britain), Publisher: Unknown, Date: 1922, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #11 ----------------------------------------
# Hyman Ashcraft (ID: #30) received 'Classics in the Classroom' from Robert Boese (ID: #239)
# Robert Boese (ID: #239) received 'American Literary Gazette and Publishers' Circular' from Hyman Ashcraft (ID: #30)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'American Literary Gazette and Publishers' Circular':
# Author(s): Unknown, Publisher: Unknown, Date: 1869, ISBN: Unknown.
#
# INFO: 'Classics in the Classroom':
# Author(s): Michael Clay Thompson, Publisher: Unknown, Date: 1991, ISBN: 1862996539.
#        ----------------------------------------------------------------------------------------------
#
# Carl Miller (ID: #132) rejected an exchange with Maria Cucco (ID: #271).
#
#        ----------------------------------------- Exchange #12 ----------------------------------------
# Judy Lundquist (ID: #63) received 'Red Shoes and Other Tales' from Diane Mason (ID: #210)
# Diane Mason (ID: #210) received 'Records of the ... Triennial Meeting of the Educational Association of China' from Judy Lundquist (ID: #63)
# Money (in €) involved in the transaction: 6.57 from Judy Lundquist to Diane Mason (Payment Method: Card)
# The books were not on each other's wishlists.
#
# INFO: 'Records of the ... Triennial Meeting of the Educational Association of China':
# Author(s): Educational Association of China, Publisher: Unknown, Date: 1893, ISBN: Unknown.
#
# INFO: 'Red Shoes and Other Tales':
# Author(s): Metaphrog, Publisher: Simon and Schuster, Date: 2015-10-13, ISBN: 1629913847.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #13 ----------------------------------------
# Lois Fisher (ID: #46) received 'WALNECK'S CLASSIC CYCLE TRADER, APRIL 2004' from Luis Dodson (ID: #114)
# Luis Dodson (ID: #114) received 'Life' from Lois Fisher (ID: #46)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Life':
# Author(s): Unknown, Publisher: Unknown, Date: Unknown, ISBN: Unknown.
#
# INFO: 'WALNECK'S CLASSIC CYCLE TRADER, APRIL 2004':
# Author(s): Causey Enterprises, LLC, Publisher: Causey Enterprises, LLC, Date: Unknown, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #14 ----------------------------------------
# Margaret Rhoades (ID: #191) received 'The East and the West' from William Hyde (ID: #230)
# William Hyde (ID: #230) received 'Educational Times' from Margaret Rhoades (ID: #191)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Educational Times':
# Author(s): Unknown, Publisher: Unknown, Date: 1893, ISBN: Unknown.
#
# INFO: 'The East and the West':
# Author(s): Unknown, Publisher: Unknown, Date: 1909, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #15 ----------------------------------------
# Charmaine Bueti (ID: #284) received 'Catalog of Reprints in Series' from Jackie Holman (ID: #246)
# Jackie Holman (ID: #246) received 'Library of Congress Catalogs' from Charmaine Bueti (ID: #284)
# No money involved in the transaction.
# Only 'Library of Congress Catalogs' was on Jackie Holman's wishlist.
#
# INFO: 'Library of Congress Catalogs':
# Author(s): Library of Congress, Publisher: Unknown, Date: 1976, ISBN: Unknown.
#
# INFO: 'Catalog of Reprints in Series':
# Author(s): Unknown, Publisher: Unknown, Date: 1950, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #16 ----------------------------------------
# Juanita Williamson (ID: #116) received 'Red Shoes and Other Tales' from Sean Owen (ID: #155)
# Sean Owen (ID: #155) received 'Catalogue of the University of Dakota for the Year ..., with Announcements for the Year ...' from Juanita Williamson (ID: #116)
# Money (in €) involved in the transaction: 5.76 from Juanita Williamson to Sean Owen (Payment Method: Cash)
# Only 'Catalogue of the University of Dakota for the Year ..., with Announcements for the Year ...' was on Sean Owen's wishlist.
#
# INFO: 'Catalogue of the University of Dakota for the Year ..., with Announcements for the Year ...':
# Author(s): University of South Dakota, Publisher: Unknown, Date: 1965, ISBN: Unknown.
#
# INFO: 'Red Shoes and Other Tales':
# Author(s): Metaphrog, Publisher: Simon and Schuster, Date: 2015-10-13, ISBN: 1629913847.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #17 ----------------------------------------
# Chris Fritz (ID: #206) received 'Catalogue - Harvard University' from Delia Mcdevitt (ID: #126)
# Delia Mcdevitt (ID: #126) received 'Domestic Noir' from Chris Fritz (ID: #206)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Domestic Noir':
# Author(s): Laura Joyce, Henry Sutton, Publisher: Springer, Date: 2018-04-23, ISBN: 3319693387.
#
# INFO: 'Catalogue - Harvard University':
# Author(s): Harvard University, Publisher: Unknown, Date: 1896, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #18 ----------------------------------------
# Joshua Rudolph (ID: #80) received 'McCall's' from Donald Dixon (ID: #1)
# Donald Dixon (ID: #1) received 'Literary Criticism from Plato to Postmodernism' from Joshua Rudolph (ID: #80)
# Money (in €) involved in the transaction: 9.14 from Joshua Rudolph to Donald Dixon (Payment Method: Cash)
# Only 'McCall's' was on Joshua Rudolph's wishlist.
#
# INFO: 'Literary Criticism from Plato to Postmodernism':
# Author(s): James Seaton, Publisher: Cambridge University Press, Date: 2014-04-28, ISBN: 1107026105.
#
# INFO: 'McCall's':
# Author(s): Unknown, Publisher: Unknown, Date: 1946, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #19 ----------------------------------------
# Kenneth Litzau (ID: #233) received 'Collier's Once a Week' from Ashley Russo (ID: #200)
# Ashley Russo (ID: #200) received 'Laser Video Guide' from Kenneth Litzau (ID: #233)
# Money (in €) involved in the transaction: 6.41 from Kenneth Litzau to Ashley Russo (Payment Method: Cash)
# The books were not on each other's wishlists.
#
# INFO: 'Laser Video Guide':
# Author(s): Unknown, Publisher: Unknown, Date: 1997, ISBN: Unknown.
#
# INFO: 'Collier's Once a Week':
# Author(s): Unknown, Publisher: Unknown, Date: 1917, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #20 ----------------------------------------
# Kim Cooperrider (ID: #170) received 'Billboard' from Thomas Denton (ID: #287)
# Thomas Denton (ID: #287) received 'The Mentor-world Traveler' from Kim Cooperrider (ID: #170)
# No money involved in the transaction.
# Only 'Billboard' was on Kim Cooperrider's wishlist.
#
# INFO: 'The Mentor-world Traveler':
# Author(s): Unknown, Publisher: Unknown, Date: 1929, ISBN: Unknown.
#
# INFO: 'Billboard':
# Author(s): Unknown, Publisher: Unknown, Date: 2006-10-28, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Fannie Crowell (ID: #145) rejected an exchange with George Lakey (ID: #7).
# Felix Wells (ID: #25) rejected an exchange with Sydney Dupre (ID: #82).
#
#        ----------------------------------------- Exchange #21 ----------------------------------------
# Eugene Little (ID: #96) received 'Bulletin' from Ronald Wynne (ID: #48)
# Ronald Wynne (ID: #48) received 'McCall's' from Eugene Little (ID: #96)
# No money involved in the transaction.
# Only 'McCall's' was on Ronald Wynne's wishlist.
#
# INFO: 'McCall's':
# Author(s): Unknown, Publisher: Unknown, Date: 1946, ISBN: Unknown.
#
# INFO: 'Bulletin':
# Author(s): Brown University, Publisher: Unknown, Date: 1942, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #22 ----------------------------------------
# Kristina Neal (ID: #69) received 'Coming Back to a Theater Near You' from Melissa Hinojosa (ID: #158)
# Melissa Hinojosa (ID: #158) received 'Sessional Papers' from Kristina Neal (ID: #69)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Sessional Papers':
# Author(s): Ontario. Legislative Assembly, Publisher: Unknown, Date: 1912, ISBN: Unknown.
#
# INFO: 'Coming Back to a Theater Near You':
# Author(s): Brian Hannan, Publisher: McFarland, Date: 2016-06-05, ISBN: 1476623899.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #23 ----------------------------------------
# Delia Mcdevitt (ID: #126) received 'The Public Schools Year Book' from Naomi Ray (ID: #298)
# Naomi Ray (ID: #298) received 'Catalogue of Princeton University' from Delia Mcdevitt (ID: #126)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Catalogue of Princeton University':
# Author(s): Princeton University, Publisher: Unknown, Date: 1907, ISBN: Unknown.
#
# INFO: 'The Public Schools Year Book':
# Author(s): Unknown, Publisher: Unknown, Date: 1915, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Johnny Soto (ID: #78) rejected an exchange with Lashaunda Diaz (ID: #85).
# Joette Thomas (ID: #149) rejected an exchange with Mary Shrader (ID: #278).
# Luis Crowe (ID: #77) rejected an exchange with Willie Prok (ID: #64).
# Sandra Frank (ID: #291) rejected an exchange with Darlene Hall (ID: #241).
# George Stepp (ID: #98) rejected an exchange with Jerrie Wise (ID: #53).
# Margaret Collins (ID: #279) rejected an exchange with Robert Boese (ID: #239).
#
#        ----------------------------------------- Exchange #24 ----------------------------------------
# Jimmy Harrington (ID: #73) received 'Agur's Prayer' from Carolyn Yanez (ID: #36)
# Carolyn Yanez (ID: #36) received 'Trattato sulle reliquie' from Jimmy Harrington (ID: #73)
# No money involved in the transaction.
# Only 'Trattato sulle reliquie' was on Carolyn Yanez's wishlist.
#
# INFO: 'Trattato sulle reliquie':
# Author(s): Jean Calvin, Publisher: Unknown, Date: 2010, ISBN: 8857502619.
#
# INFO: 'Agur's Prayer':
# Author(s): Unknown, Publisher: Unknown, Date: 1867, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #25 ----------------------------------------
# Cassandra Miles (ID: #51) received 'New York Times Saturday Book Review Supplement' from Lisa Alexander (ID: #118)
# Lisa Alexander (ID: #118) received 'Billboard' from Cassandra Miles (ID: #51)
# Money (in €) involved in the transaction: 7.89 from Cassandra Miles to Lisa Alexander (Payment Method: PayPal)
# Only 'New York Times Saturday Book Review Supplement' was on Cassandra Miles's wishlist.
#
# INFO: 'Billboard':
# Author(s): Unknown, Publisher: Unknown, Date: 2004-04-03, ISBN: Unknown.
#
# INFO: 'New York Times Saturday Book Review Supplement':
# Author(s): Unknown, Publisher: Unknown, Date: 1962-05, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #26 ----------------------------------------
# Cassandra Miles (ID: #51) received 'Courses and Degrees' from Irma Fanning (ID: #292)
# Irma Fanning (ID: #292) received 'Manga Classics: The Stories of Edgar Allan Poe' from Cassandra Miles (ID: #51)
# Money (in €) involved in the transaction: 6.54 from Cassandra Miles to Irma Fanning (Payment Method: Card)
# Only 'Courses and Degrees' was on Cassandra Miles's wishlist.
#
# INFO: 'Manga Classics: The Stories of Edgar Allan Poe':
# Author(s): Edgar Allan Poe, Stacy King, Publisher: Manga Classics, Date: Unknown, ISBN: Unknown.
#
# INFO: 'Courses and Degrees':
# Author(s): Stanford University, Publisher: Unknown, Date: 1981, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #27 ----------------------------------------
# Ruth Smith (ID: #135) received 'A Catalog of Phonorecordings of Music and Oral Data Held by the Archives of Traditional Music' from Peter Zwick (ID: #3)
# Peter Zwick (ID: #3) received 'The Yearbook of the Universities of the Empire' from Ruth Smith (ID: #135)
# Money (in €) involved in the transaction: 6.01 from Peter Zwick to Ruth Smith (Payment Method: SamsungPay)
# Both books were on each other's wishlists.
#
# INFO: 'The Yearbook of the Universities of the Empire':
# Author(s): Unknown, Publisher: Unknown, Date: 1921, ISBN: Unknown.
#
# INFO: 'A Catalog of Phonorecordings of Music and Oral Data Held by the Archives of Traditional Music':
# Author(s): Indiana University. Archives of Traditional Music, Publisher: Boston : G. K. Hall, Date: 1975, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #28 ----------------------------------------
# Ashley Russo (ID: #200) received 'Books and Pamphlets, Including Serials and Contributions to Periodicals' from Carolyn Millard (ID: #144)
# Carolyn Millard (ID: #144) received 'Official Documents, Comprising the Department and Other Reports Made to the Governor, Senate and House of Representatives of Pennsylvania' from Ashley Russo (ID: #200)
# Money (in €) involved in the transaction: 2.48 from Ashley Russo to Carolyn Millard (Payment Method: Cash)
# Only 'Books and Pamphlets, Including Serials and Contributions to Periodicals' was on Ashley Russo's wishlist.
#
# INFO: 'Official Documents, Comprising the Department and Other Reports Made to the Governor, Senate and House of Representatives of Pennsylvania':
# Author(s): Unknown, Publisher: Unknown, Date: 1892, ISBN: Unknown.
#
# INFO: 'Books and Pamphlets, Including Serials and Contributions to Periodicals':
# Author(s): Library of Congress. Copyright Office, Publisher: Unknown, Date: 1973, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Peter Cavaretta (ID: #59) rejected an exchange with Heidi Grimes (ID: #11).
# Gary Merrill (ID: #281) rejected an exchange with Stanley Reid (ID: #87).
#
#        ----------------------------------------- Exchange #29 ----------------------------------------
# Charles Lemons (ID: #270) received 'Le case e i monumenti di Pompei nell'opera di Fausto e Felice Niccolini' from Barney Largent (ID: #282)
# Barney Largent (ID: #282) received 'Report of the Superintendent of Public Instruction' from Charles Lemons (ID: #270)
# No money involved in the transaction.
# Only 'Le case e i monumenti di Pompei nell'opera di Fausto e Felice Niccolini' was on Charles Lemons's wishlist.
#
# INFO: 'Report of the Superintendent of Public Instruction':
# Author(s): Michigan. Department of Public Instruction, Publisher: Unknown, Date: 1893, ISBN: Unknown.
#
# INFO: 'Le case e i monumenti di Pompei nell'opera di Fausto e Felice Niccolini':
# Author(s): Roberto Cassanelli, Publisher: De Agostini, Date: 1997-01-01, ISBN: 8841543795.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #30 ----------------------------------------
# Timothy Fredrick (ID: #28) received 'Gramophone' from Daniel Hoyt (ID: #293)
# Daniel Hoyt (ID: #293) received 'Greece & Rome' from Timothy Fredrick (ID: #28)
# No money involved in the transaction.
# Only 'Greece & Rome' was on Daniel Hoyt's wishlist.
#
# INFO: 'Greece & Rome':
# Author(s): Unknown, Publisher: Unknown, Date: 1962, ISBN: Unknown.
#
# INFO: 'Gramophone':
# Author(s): Unknown, Publisher: Unknown, Date: 2000, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #31 ----------------------------------------
# Robert Scott (ID: #35) received 'Reading Their World' from Francis Williams (ID: #252)
# Francis Williams (ID: #252) received 'The East and the West' from Robert Scott (ID: #35)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'The East and the West':
# Author(s): Unknown, Publisher: Unknown, Date: 1909, ISBN: Unknown.
#
# INFO: 'Reading Their World':
# Author(s): Virginia R. Monseau, Gary M. Salvner, Publisher: Boynton/Cook, Date: 2000, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Joseph Alexander (ID: #39) rejected an exchange with Martha Carter (ID: #68).
# Trevor Cordova (ID: #289) rejected an exchange with Jeffrey Walter (ID: #52).
#
#        ----------------------------------------- Exchange #32 ----------------------------------------
# William Hyde (ID: #230) received 'Saturday Review' from Steven Warren (ID: #166)
# Steven Warren (ID: #166) received 'Harper's Magazine' from William Hyde (ID: #230)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Harper's Magazine':
# Author(s): Lee Foster Hartman, Frederick Lewis Allen, Publisher: Unknown, Date: 1956, ISBN: Unknown.
#
# INFO: 'Saturday Review':
# Author(s): Unknown, Publisher: Unknown, Date: 1869, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #33 ----------------------------------------
# Mary Shrader (ID: #278) received 'McCall's' from Joshua Rudolph (ID: #80)
# Joshua Rudolph (ID: #80) received 'Life' from Mary Shrader (ID: #278)
# Money (in €) involved in the transaction: 5.51 from Joshua Rudolph to Mary Shrader (Payment Method: SamsungPay)
# Only 'Life' was on Joshua Rudolph's wishlist.
#
# INFO: 'Life':
# Author(s): Unknown, Publisher: Unknown, Date: Unknown, ISBN: Unknown.
#
# INFO: 'McCall's':
# Author(s): Unknown, Publisher: Unknown, Date: 1946, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #34 ----------------------------------------
# Robert Boese (ID: #239) received 'The Encyclopedia of Confucianism' from Donald Birch (ID: #49)
# Donald Birch (ID: #49) received 'Thomas Hardy, Time and Narrative' from Robert Boese (ID: #239)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Thomas Hardy, Time and Narrative':
# Author(s): K. Ireland, Publisher: Springer, Date: 2014-07-29, ISBN: 1137367725.
#
# INFO: 'The Encyclopedia of Confucianism':
# Author(s): Xinzhong Yao, Publisher: Routledge, Date: 2015-05-11, ISBN: 131779348X.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #35 ----------------------------------------
# Eleanor Hayes (ID: #18) received 'Bibliographical Contributions' from Rogelio Miller (ID: #277)
# Rogelio Miller (ID: #277) received 'Billboard' from Eleanor Hayes (ID: #18)
# No money involved in the transaction.
# Only 'Bibliographical Contributions' was on Eleanor Hayes's wishlist.
#
# INFO: 'Billboard':
# Author(s): Unknown, Publisher: Unknown, Date: 2005-04-16, ISBN: Unknown.
#
# INFO: 'Bibliographical Contributions':
# Author(s): Harvard University. Library, Publisher: Unknown, Date: 1890, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #36 ----------------------------------------
# Veronica Salcedo (ID: #203) received 'Il mondo che abbiamo perduto. L'Inghilterra prima dell'età industriale' from Margaret Collins (ID: #279)
# Margaret Collins (ID: #279) received 'Teaching Psychology and the Socratic Method' from Veronica Salcedo (ID: #203)
# No money involved in the transaction.
# Only 'Teaching Psychology and the Socratic Method' was on Margaret Collins's wishlist.
#
# INFO: 'Teaching Psychology and the Socratic Method':
# Author(s): James J. Dillon, Publisher: Springer, Date: 2016-11-18, ISBN: 1349950505.
#
# INFO: 'Il mondo che abbiamo perduto. L'Inghilterra prima dell'età industriale':
# Author(s): P. Laslett, Publisher: Editoriale Jaca Book, Date: 1997, ISBN: 8816400439.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #37 ----------------------------------------
# Mark Wierzbicki (ID: #193) received 'Victorian Literature at St. Deiniol's Library' from Robert Scott (ID: #35)
# Robert Scott (ID: #35) received 'CEA Critic' from Mark Wierzbicki (ID: #193)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'CEA Critic':
# Author(s): Unknown, Publisher: Unknown, Date: 1956, ISBN: Unknown.
#
# INFO: 'Victorian Literature at St. Deiniol's Library':
# Author(s): St. Deiniol's Library, Publisher: Unknown, Date: 1985, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #38 ----------------------------------------
# Sharon Craze (ID: #295) received 'Monographic Series' from Edwin Munoz (ID: #94)
# Edwin Munoz (ID: #94) received 'The Oxford Handbook of Classical Chinese Literature (1000 BCE-900 CE)' from Sharon Craze (ID: #295)
# Money (in €) involved in the transaction: 8.53 from Edwin Munoz to Sharon Craze (Payment Method: SamsungPay)
# The books were not on each other's wishlists.
#
# INFO: 'The Oxford Handbook of Classical Chinese Literature (1000 BCE-900 CE)':
# Author(s): Wiebke Denecke, Wai-yee Li, Xiaofei Tian, Publisher: Oxford University Press, Date: 2017, ISBN: 0199356599.
#
# INFO: 'Monographic Series':
# Author(s): Library of Congress, Publisher: Unknown, Date: 1982, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #39 ----------------------------------------
# Valerie Reid (ID: #168) received 'American Literary Gazette and Publishers' Circular' from Eva Kelly (ID: #43)
# Eva Kelly (ID: #43) received 'Libraries' from Valerie Reid (ID: #168)
# Money (in €) involved in the transaction: 2.87 from Eva Kelly to Valerie Reid (Payment Method: GooglePay)
# Both books were on each other's wishlists.
#
# INFO: 'Libraries':
# Author(s): Mary Eileen Ahern, Publisher: Unknown, Date: 1926, ISBN: Unknown.
#
# INFO: 'American Literary Gazette and Publishers' Circular':
# Author(s): Unknown, Publisher: Unknown, Date: 1869, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #40 ----------------------------------------
# Peter Zwick (ID: #3) received 'Billboard' from Darlene Hall (ID: #241)
# Darlene Hall (ID: #241) received 'Documents of the Senate of the State of New York' from Peter Zwick (ID: #3)
# No money involved in the transaction.
# Only 'Documents of the Senate of the State of New York' was on Darlene Hall's wishlist.
#
# INFO: 'Documents of the Senate of the State of New York':
# Author(s): New York (State). Legislature. Senate, Publisher: Unknown, Date: 1902, ISBN: Unknown.
#
# INFO: 'Billboard':
# Author(s): Unknown, Publisher: Unknown, Date: 2007-07-21, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #41 ----------------------------------------
# Donald Flagg (ID: #106) received 'International Currency Review' from Shawna Caron (ID: #89)
# Shawna Caron (ID: #89) received 'Combined List of Books for Elementary and Junior High School Libraries' from Donald Flagg (ID: #106)
# Money (in €) involved in the transaction: 8.57 from Donald Flagg to Shawna Caron (Payment Method: SamsungPay)
# Both books were on each other's wishlists.
#
# INFO: 'Combined List of Books for Elementary and Junior High School Libraries':
# Author(s): Unknown, Publisher: Unknown, Date: 1896, ISBN: Unknown.
#
# INFO: 'International Currency Review':
# Author(s): Unknown, Publisher: Unknown, Date: 2007, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #42 ----------------------------------------
# Mary Mcbride (ID: #254) received 'Apophoreta' from Thomas Aquino (ID: #215)
# Thomas Aquino (ID: #215) received 'Bibliography' from Mary Mcbride (ID: #254)
# No money involved in the transaction.
# Only 'Bibliography' was on Thomas Aquino's wishlist.
#
# INFO: 'Bibliography':
# Author(s): Unknown, Publisher: Unknown, Date: 1900, ISBN: Unknown.
#
# INFO: 'Apophoreta':
# Author(s): Jeremiah Reedy, Publisher: Unknown, Date: 1985, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #43 ----------------------------------------
# Darin Sherman (ID: #109) received 'Reading Their World' from Earl Schultz (ID: #251)
# Earl Schultz (ID: #251) received 'The English Catalogue of Books' from Darin Sherman (ID: #109)
# Money (in €) involved in the transaction: 7.14 from Darin Sherman to Earl Schultz (Payment Method: GooglePay)
# Both books were on each other's wishlists.
#
# INFO: 'The English Catalogue of Books':
# Author(s): Sampson Low, Publisher: Unknown, Date: 1926, ISBN: Unknown.
#
# INFO: 'Reading Their World':
# Author(s): Virginia R. Monseau, Gary M. Salvner, Publisher: Boynton/Cook, Date: 2000, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #44 ----------------------------------------
# Margo Mann (ID: #171) received 'The Classic and the Beautiful from the Literature of Three Thousand Years' from Shawna Caron (ID: #89)
# Shawna Caron (ID: #89) received 'Educational Times' from Margo Mann (ID: #171)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Educational Times':
# Author(s): Unknown, Publisher: Unknown, Date: 1893, ISBN: Unknown.
#
# INFO: 'The Classic and the Beautiful from the Literature of Three Thousand Years':
# Author(s): Henry Coppée, Publisher: Unknown, Date: 1894, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #45 ----------------------------------------
# John Jones (ID: #9) received 'Catalogue of Title-entries of Books and Other Articles Entered in the Office of the Librarian of Congress, at Washington, Under the Copyright Law ... Wherein the Copyright Has Been Completed by the Deposit of Two Copies in the Office' from Trevor Cordova (ID: #289)
# Trevor Cordova (ID: #289) received 'Wardrobe' from John Jones (ID: #9)
# Money (in €) involved in the transaction: 2.11 from John Jones to Trevor Cordova (Payment Method: ApplePay)
# Only 'Catalogue of Title-entries of Books and Other Articles Entered in the Office of the Librarian of Congress, at Washington, Under the Copyright Law ... Wherein the Copyright Has Been Completed by the Deposit of Two Copies in the Office' was on John Jones's wishlist.
#
# INFO: 'Wardrobe':
# Author(s): Susie Faux, Philippa Davies, Publisher: Piatkus Books, Date: 1988, ISBN: 0861887263.
#
# INFO: 'Catalogue of Title-entries of Books and Other Articles Entered in the Office of the Librarian of Congress, at Washington, Under the Copyright Law ... Wherein the Copyright Has Been Completed by the Deposit of Two Copies in the Office':
# Author(s): Library of Congress. Copyright Office, Publisher: Unknown, Date: 1975, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Delia Mcdevitt (ID: #126) rejected an exchange with Jerrie Wise (ID: #53).
# Shirley Kastner (ID: #266) rejected an exchange with Joette Thomas (ID: #149).
#
#        ----------------------------------------- Exchange #46 ----------------------------------------
# Shelia Charles (ID: #26) received 'Annual Bulletin ...' from Carolyn Yanez (ID: #36)
# Carolyn Yanez (ID: #36) received 'Exercises and Tests on English Classics' from Shelia Charles (ID: #26)
# No money involved in the transaction.
# Only 'Exercises and Tests on English Classics' was on Carolyn Yanez's wishlist.
#
# INFO: 'Exercises and Tests on English Classics':
# Author(s): Mary Louise Harris, Publisher: Unknown, Date: 1928, ISBN: Unknown.
#
# INFO: 'Annual Bulletin ...':
# Author(s): Unknown, Publisher: Unknown, Date: 1913, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #47 ----------------------------------------
# Eleanor Hayes (ID: #18) received 'Annual Report of the State of Georgia, Department of Education' from Steven Koslosky (ID: #75)
# Steven Koslosky (ID: #75) received 'A History of Chinese Science and Technology' from Eleanor Hayes (ID: #18)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'A History of Chinese Science and Technology':
# Author(s): Yongxiang Lu, Publisher: Springer, Date: 2014-10-10, ISBN: 3662441667.
#
# INFO: 'Annual Report of the State of Georgia, Department of Education':
# Author(s): Georgia. Department of Education, Publisher: Unknown, Date: 1896, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Ida Kerwood (ID: #151) rejected an exchange with Roberta Stafford (ID: #169).
#
#        ----------------------------------------- Exchange #48 ----------------------------------------
# James Carpenter (ID: #31) received 'Oxford University Gazette' from Eloise Gutierrez (ID: #179)
# Eloise Gutierrez (ID: #179) received 'Books in Series' from James Carpenter (ID: #31)
# No money involved in the transaction.
# Only 'Books in Series' was on Eloise Gutierrez's wishlist.
#
# INFO: 'Books in Series':
# Author(s): Unknown, Publisher: Unknown, Date: 1985, ISBN: Unknown.
#
# INFO: 'Oxford University Gazette':
# Author(s): University of Oxford, Publisher: Unknown, Date: 1901, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #49 ----------------------------------------
# John Dugger (ID: #253) received 'The American Music Teacher' from Cecelia Pouncey (ID: #44)
# Cecelia Pouncey (ID: #44) received 'Final Part of Henry the Fourth' from John Dugger (ID: #253)
# No money involved in the transaction.
# Only 'Final Part of Henry the Fourth' was on Cecelia Pouncey's wishlist.
#
# INFO: 'Final Part of Henry the Fourth':
# Author(s): William Shakespeare, Publisher: Orient Blackswan, Date: 2001-07-25, ISBN: 8125020055.
#
# INFO: 'The American Music Teacher':
# Author(s): Unknown, Publisher: Unknown, Date: 1990, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Shirley Kastner (ID: #266) rejected an exchange with Toni Perdomo (ID: #5).
#
#        ----------------------------------------- Exchange #50 ----------------------------------------
# Beverly Christensen (ID: #276) received 'Apophoreta' from Emily Simmons (ID: #154)
# Emily Simmons (ID: #154) received 'Newsweek' from Beverly Christensen (ID: #276)
# Money (in €) involved in the transaction: 4.29 from Emily Simmons to Beverly Christensen (Payment Method: Card)
# Only 'Newsweek' was on Emily Simmons's wishlist.
#
# INFO: 'Newsweek':
# Author(s): Unknown, Publisher: Unknown, Date: 1956, ISBN: Unknown.
#
# INFO: 'Apophoreta':
# Author(s): Jeremiah Reedy, Publisher: Unknown, Date: 1985, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Peter Zwick (ID: #3) rejected an exchange with Carrie Baxter (ID: #201).
# Susan Fowler (ID: #72) rejected an exchange with Robert Wolchesky (ID: #84).
#
#        ----------------------------------------- Exchange #51 ----------------------------------------
# Jerry Coleman (ID: #105) received 'A History of Chinese Science and Technology' from Steven Koslosky (ID: #75)
# Steven Koslosky (ID: #75) received 'Calendar' from Jerry Coleman (ID: #105)
# Money (in €) involved in the transaction: 5.81 from Jerry Coleman to Steven Koslosky (Payment Method: Cash)
# Both books were on each other's wishlists.
#
# INFO: 'Calendar':
# Author(s): University of Manchester, Publisher: Unknown, Date: 1917, ISBN: Unknown.
#
# INFO: 'A History of Chinese Science and Technology':
# Author(s): Yongxiang Lu, Publisher: Springer, Date: 2014-10-10, ISBN: 3662441667.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #52 ----------------------------------------
# Jo Ayaia (ID: #58) received 'Manga Classics: Macbeth: Modern English Edition' from Eloise Gutierrez (ID: #179)
# Eloise Gutierrez (ID: #179) received 'Guide to Reprints' from Jo Ayaia (ID: #58)
# No money involved in the transaction.
# Only 'Manga Classics: Macbeth: Modern English Edition' was on Jo Ayaia's wishlist.
#
# INFO: 'Guide to Reprints':
# Author(s): Unknown, Publisher: Unknown, Date: 2005, ISBN: Unknown.
#
# INFO: 'Manga Classics: Macbeth: Modern English Edition':
# Author(s): William Shakespeare, Michael Barltrop, Crystal S. Chan, Publisher: Manga Classics, Date: Unknown, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #53 ----------------------------------------
# Donald Birch (ID: #49) received 'Tutti i romanzi' from Gerardo Hassinger (ID: #141)
# Gerardo Hassinger (ID: #141) received 'Library Journal' from Donald Birch (ID: #49)
# Money (in €) involved in the transaction: 8.93 from Donald Birch to Gerardo Hassinger (Payment Method: Cash)
# Both books were on each other's wishlists.
#
# INFO: 'Library Journal':
# Author(s): Melvil Dewey, Richard Rogers Bowker, L. Pylodet, Charles Ammi Cutter, Bertine Emma Weston, Karl Brown, Helen E. Wessells, Publisher: Unknown, Date: 1885, ISBN: Unknown.
#
# INFO: 'Tutti i romanzi':
# Author(s): Jane Austen, Publisher: Newton Compton Editori, Date: 2010-11-05, ISBN: 8854125768.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #54 ----------------------------------------
# Gary Merrill (ID: #281) received 'Il meglio della vita' from Jeffrey Walter (ID: #52)
# Jeffrey Walter (ID: #52) received 'Oxford University Gazette' from Gary Merrill (ID: #281)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'Oxford University Gazette':
# Author(s): University of Oxford, Publisher: Unknown, Date: 1901, ISBN: Unknown.
#
# INFO: 'Il meglio della vita':
# Author(s): Rona Jaffe, Publisher: Neri Pozza Editore, Date: 2017-12-15T00:00:00+01:00, ISBN: 8865594926.
#        ----------------------------------------------------------------------------------------------
#
# Naomi Wilkins (ID: #101) rejected an exchange with Rosemarie Kuhn (ID: #202).
#
#        ----------------------------------------- Exchange #55 ----------------------------------------
# Anna Richardson (ID: #214) received 'The American Catalogue ... July 1, 1876-Dec. 31, 1910' from Suzette Musgrove (ID: #62)
# Suzette Musgrove (ID: #62) received 'Jazz Journal International' from Anna Richardson (ID: #214)
# No money involved in the transaction.
# Only 'The American Catalogue ... July 1, 1876-Dec. 31, 1910' was on Anna Richardson's wishlist.
#
# INFO: 'Jazz Journal International':
# Author(s): Unknown, Publisher: Unknown, Date: 1997, ISBN: Unknown.
#
# INFO: 'The American Catalogue ... July 1, 1876-Dec. 31, 1910':
# Author(s): Unknown, Publisher: Unknown, Date: 1941, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #56 ----------------------------------------
# Jeffrey Walter (ID: #52) received 'The Marsh Arabs' from Kimberly Ham (ID: #110)
# Kimberly Ham (ID: #110) received 'Wardrobe' from Jeffrey Walter (ID: #52)
# No money involved in the transaction.
# Only 'Wardrobe' was on Kimberly Ham's wishlist.
#
# INFO: 'Wardrobe':
# Author(s): Susie Faux, Philippa Davies, Publisher: Piatkus Books, Date: 1988, ISBN: 0861887263.
#
# INFO: 'The Marsh Arabs':
# Author(s): Wilfred Thesiger, Publisher: Penguin, Date: 2008-01-02, ISBN: 1436265584.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #57 ----------------------------------------
# Robert Kissinger (ID: #113) received 'A History of Chinese Science and Technology' from William Burgess (ID: #119)
# William Burgess (ID: #119) received '25 Great Sax Solos' from Robert Kissinger (ID: #113)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: '25 Great Sax Solos':
# Author(s): Eric J. Morones, Publisher: Hal Leonard Corporation, Date: 2008-04-01, ISBN: 149503139X.
#
# INFO: 'A History of Chinese Science and Technology':
# Author(s): Yongxiang Lu, Publisher: Springer, Date: 2014-10-10, ISBN: 3662441667.
#        ----------------------------------------------------------------------------------------------
#
# Kenneth Isbell (ID: #127) rejected an exchange with Michelle King (ID: #197).
#
#        ----------------------------------------- Exchange #58 ----------------------------------------
# Matthew Winstead (ID: #81) received '淡江評論' from Daryl Bassler (ID: #217)
# Daryl Bassler (ID: #217) received 'Proceedings of the Classical Association' from Matthew Winstead (ID: #81)
# No money involved in the transaction.
# Only 'Proceedings of the Classical Association' was on Daryl Bassler's wishlist.
#
# INFO: 'Proceedings of the Classical Association':
# Author(s): Classical Association (Great Britain), Publisher: Unknown, Date: 1922, ISBN: Unknown.
#
# INFO: '淡江評論':
# Author(s): Unknown, Publisher: Unknown, Date: 1973, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #59 ----------------------------------------
# Sean Owen (ID: #155) received 'The Journal of Education' from Sydney Dupre (ID: #82)
# Sydney Dupre (ID: #82) received 'Il mondo di Odisseo' from Sean Owen (ID: #155)
# No money involved in the transaction.
# ...
#
# INFO: 'Tradition and Modernity':
# Author(s): Unknown, Publisher: BRILL, Date: 2009, ISBN: 9004165789.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #254 ----------------------------------------
# Pam Whitney (ID: #290) received 'Reports of the Minister of Education' from Lisa Alexander (ID: #118)
# Lisa Alexander (ID: #118) received 'The Yearbook of the Universities of the Commonwealth' from Pam Whitney (ID: #290)
# Money (in €) involved in the transaction: 8.95 from Lisa Alexander to Pam Whitney (Payment Method: PayPal)
# Both books were on each other's wishlists.
#
# INFO: 'The Yearbook of the Universities of the Commonwealth':
# Author(s): Unknown, Publisher: Unknown, Date: 1923, ISBN: Unknown.
#
# INFO: 'Reports of the Minister of Education':
# Author(s): Ontario. Department of Education, Publisher: Unknown, Date: 1911, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #255 ----------------------------------------
# Peggy Mcgarey (ID: #147) received 'Annual Report of the Regents' from Isaiah Thomsen (ID: #146)
# Isaiah Thomsen (ID: #146) received 'Tutti i romanzi' from Peggy Mcgarey (ID: #147)
# Money (in €) involved in the transaction: 7.69 from Isaiah Thomsen to Peggy Mcgarey (Payment Method: PayPal)
# Only 'Annual Report of the Regents' was on Peggy Mcgarey's wishlist.
#
# INFO: 'Tutti i romanzi':
# Author(s): Jane Austen, Publisher: Newton Compton Editori, Date: 2010-11-05, ISBN: 8854125768.
#
# INFO: 'Annual Report of the Regents':
# Author(s): University of the State of New York, Publisher: Unknown, Date: 1881, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #256 ----------------------------------------
# Gina Fong (ID: #236) received 'Billboard' from Jaime Verdugo (ID: #243)
# Jaime Verdugo (ID: #243) received 'The Mentor-world Traveler' from Gina Fong (ID: #236)
# No money involved in the transaction.
# Both books were on each other's wishlists.
#
# INFO: 'The Mentor-world Traveler':
# Author(s): Unknown, Publisher: Unknown, Date: 1929, ISBN: Unknown.
#
# INFO: 'Billboard':
# Author(s): Unknown, Publisher: Unknown, Date: 2002-12-14, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #257 ----------------------------------------
# Cristina Grimes (ID: #54) received 'Manga Classics: The Adventures of Tom Sawyer' from Eva Kelly (ID: #43)
# Eva Kelly (ID: #43) received 'Educational Times' from Cristina Grimes (ID: #54)
# Money (in €) involved in the transaction: 2.63 from Eva Kelly to Cristina Grimes (Payment Method: Card)
# Only 'Manga Classics: The Adventures of Tom Sawyer' was on Cristina Grimes's wishlist.
#
# INFO: 'Educational Times':
# Author(s): Unknown, Publisher: Unknown, Date: 1893, ISBN: Unknown.
#
# INFO: 'Manga Classics: The Adventures of Tom Sawyer':
# Author(s): Mark Twain, Crystal S.Chan, Publisher: Manga Classics, Date: Unknown, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #258 ----------------------------------------
# Steven Warren (ID: #166) received 'Du Pont Magazine' from James Hornsby (ID: #162)
# James Hornsby (ID: #162) received 'Harper's Magazine' from Steven Warren (ID: #166)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Harper's Magazine':
# Author(s): Lee Foster Hartman, Frederick Lewis Allen, Publisher: Unknown, Date: 1956, ISBN: Unknown.
#
# INFO: 'Du Pont Magazine':
# Author(s): Unknown, Publisher: Unknown, Date: 1927, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #259 ----------------------------------------
# Blanca Pleasant (ID: #176) received 'Circular' from Eleanor Hayes (ID: #18)
# Eleanor Hayes (ID: #18) received 'The American Music Teacher' from Blanca Pleasant (ID: #176)
# Money (in €) involved in the transaction: 7.81 from Eleanor Hayes to Blanca Pleasant (Payment Method: Card)
# Only 'Circular' was on Blanca Pleasant's wishlist.
#
# INFO: 'The American Music Teacher':
# Author(s): Unknown, Publisher: Unknown, Date: 1990, ISBN: Unknown.
#
# INFO: 'Circular':
# Author(s): Unknown, Publisher: Unknown, Date: 1918, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #260 ----------------------------------------
# Cheryl Butterworth (ID: #285) received 'Bibliography' from Thomas Aquino (ID: #215)
# Thomas Aquino (ID: #215) received 'Billboard' from Cheryl Butterworth (ID: #285)
# Money (in €) involved in the transaction: 4.64 from Thomas Aquino to Cheryl Butterworth (Payment Method: GooglePay)
# Both books were on each other's wishlists.
#
# INFO: 'Billboard':
# Author(s): Unknown, Publisher: Unknown, Date: 2002-12-14, ISBN: Unknown.
#
# INFO: 'Bibliography':
# Author(s): Unknown, Publisher: Unknown, Date: 1900, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Stuart Allison (ID: #255) rejected an exchange with Josephine Riley (ID: #6).
# Lori King (ID: #38) rejected an exchange with Rosemarie Kuhn (ID: #202).
#
#        ----------------------------------------- Exchange #261 ----------------------------------------
# Margaret Collins (ID: #279) received 'Music and Musicians International' from Karin Brock (ID: #198)
# Karin Brock (ID: #198) received 'Register of the Faculties and Students' from Margaret Collins (ID: #279)
# Money (in €) involved in the transaction: 5.88 from Karin Brock to Margaret Collins (Payment Method: Card)
# Both books were on each other's wishlists.
#
# INFO: 'Register of the Faculties and Students':
# Author(s): Georgetown University, Publisher: Unknown, Date: 1893, ISBN: Unknown.
#
# INFO: 'Music and Musicians International':
# Author(s): Unknown, Publisher: Unknown, Date: 1987, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Eva Kelly (ID: #43) rejected an exchange with Virgilio Mack (ID: #186).
# Jeffery Anderson (ID: #143) rejected an exchange with Garrett Devine (ID: #42).
# Donna Freeman (ID: #180) rejected an exchange with Cristina Grimes (ID: #54).
#
#        ----------------------------------------- Exchange #262 ----------------------------------------
# Veronica Salcedo (ID: #203) received 'McGraw-Hill Education SAT Subject Test Literature 3rd Ed.' from Lynn Sorkin (ID: #104)
# Lynn Sorkin (ID: #104) received 'Life' from Veronica Salcedo (ID: #203)
# No money involved in the transaction.
# Only 'McGraw-Hill Education SAT Subject Test Literature 3rd Ed.' was on Veronica Salcedo's wishlist.
#
# INFO: 'Life':
# Author(s): Unknown, Publisher: Unknown, Date: Unknown, ISBN: Unknown.
#
# INFO: 'McGraw-Hill Education SAT Subject Test Literature 3rd Ed.':
# Author(s): Stephanie Muntone, Publisher: McGraw Hill Professional, Date: 2016-01-01, ISBN: 1259586871.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #263 ----------------------------------------
# Willie Potts (ID: #41) received 'The Journal of Hellenic Studies' from Ida Crumpton (ID: #122)
# Ida Crumpton (ID: #122) received 'VCR and Film Catalog' from Willie Potts (ID: #41)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'VCR and Film Catalog':
# Author(s): Unknown, Publisher: Unknown, Date: 1987, ISBN: Unknown.
#
# INFO: 'The Journal of Hellenic Studies':
# Author(s): Unknown, Publisher: Unknown, Date: 1924, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #264 ----------------------------------------
# Monica Driver (ID: #45) received 'Library Manual for High Schools' from Jeffrey Walter (ID: #52)
# Jeffrey Walter (ID: #52) received 'Brands and Their Companies' from Monica Driver (ID: #45)
# Money (in €) involved in the transaction: 4.07 from Monica Driver to Jeffrey Walter (Payment Method: PayPal)
# Both books were on each other's wishlists.
#
# INFO: 'Brands and Their Companies':
# Author(s): Unknown, Publisher: Unknown, Date: 2003, ISBN: 0787689513.
#
# INFO: 'Library Manual for High Schools':
# Author(s): Indiana. Department of Public Instruction, Publisher: Unknown, Date: 1923, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #265 ----------------------------------------
# Karin Brock (ID: #198) received 'Dizionario delle letterature classiche' from Maxine Rutherford (ID: #83)
# Maxine Rutherford (ID: #83) received 'The Most Complete Food Counter' from Karin Brock (ID: #198)
# No money involved in the transaction.
# Only 'Dizionario delle letterature classiche' was on Karin Brock's wishlist.
#
# INFO: 'The Most Complete Food Counter':
# Author(s): Annette B. Natow, Jo-Ann Heslin, Publisher: Simon and Schuster, Date: 1999, ISBN: 0671025619.
#
# INFO: 'Dizionario delle letterature classiche':
# Author(s): Anna Maria Farcito, Publisher: Unknown, Date: 1993, ISBN: 8806130951.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #266 ----------------------------------------
# Kimberly Ham (ID: #110) received 'Icons of the American Comic Book [2 volumes]' from Georgia Hall (ID: #117)
# Georgia Hall (ID: #117) received 'The Literary Year-book' from Kimberly Ham (ID: #110)
# Money (in €) involved in the transaction: 9.05 from Kimberly Ham to Georgia Hall (Payment Method: PayPal)
# Both books were on each other's wishlists.
#
# INFO: 'The Literary Year-book':
# Author(s): Frederick George Aflalo, Joseph Jacobs, Herbert Arthur Morrah, Henry Gilbert, Basil Stewart, Mark Meredith, Publisher: Unknown, Date: 1913, ISBN: Unknown.
#
# INFO: 'Icons of the American Comic Book [2 volumes]':
# Author(s): Randy Duncan, Matthew J. Smith, Publisher: Bloomsbury Publishing USA, Date: 2013-01-29, ISBN: 0313399247.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #267 ----------------------------------------
# Jimmy Laroche (ID: #103) received 'The Journal of Education' from Garrett Devine (ID: #42)
# Garrett Devine (ID: #42) received 'Theses on Tibetology in China' from Jimmy Laroche (ID: #103)
# Money (in €) involved in the transaction: 4.99 from Garrett Devine to Jimmy Laroche (Payment Method: Cash)
# The books were not on each other's wishlists.
#
# INFO: 'Theses on Tibetology in China':
# Author(s): Zugui Liao, Publisher: Unknown, Date: 1996, ISBN: Unknown.
#
# INFO: 'The Journal of Education':
# Author(s): Unknown, Publisher: Unknown, Date: 1938, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #268 ----------------------------------------
# Ida Kerwood (ID: #151) received 'The East and the West' from Barbara Maynard (ID: #32)
# Barbara Maynard (ID: #32) received 'Catalogue of Title-entries of Books and Other Articles Entered in the Office of the Librarian of Congress, at Washington, Under the Copyright Law ... Wherein the Copyright Has Been Completed by the Deposit of Two Copies in the Office' from Ida Kerwood (ID: #151)
# Money (in €) involved in the transaction: 6.94 from Barbara Maynard to Ida Kerwood (Payment Method: ApplePay)
# Both books were on each other's wishlists.
#
# INFO: 'Catalogue of Title-entries of Books and Other Articles Entered in the Office of the Librarian of Congress, at Washington, Under the Copyright Law ... Wherein the Copyright Has Been Completed by the Deposit of Two Copies in the Office':
# Author(s): Library of Congress. Copyright Office, Publisher: Unknown, Date: 1975, ISBN: Unknown.
#
# INFO: 'The East and the West':
# Author(s): Unknown, Publisher: Unknown, Date: 1909, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Robert Wolchesky (ID: #84) rejected an exchange with Patrick Mashak (ID: #23).
#
#        ----------------------------------------- Exchange #269 ----------------------------------------
# Kenneth Litzau (ID: #233) received 'The Inter-mountain Educator' from Stephanie Richardson (ID: #258)
# Stephanie Richardson (ID: #258) received 'Reports of the Provost and Treausurer' from Kenneth Litzau (ID: #233)
# No money involved in the transaction.
# Only 'The Inter-mountain Educator' was on Kenneth Litzau's wishlist.
#
# INFO: 'Reports of the Provost and Treausurer':
# Author(s): University of Pennsylvania, Publisher: Unknown, Date: 1906, ISBN: Unknown.
#
# INFO: 'The Inter-mountain Educator':
# Author(s): Unknown, Publisher: Unknown, Date: 1919, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
#
#        ----------------------------------------- Exchange #270 ----------------------------------------
# Katherine Hem (ID: #207) received 'Oxford University Gazette' from Lori King (ID: #38)
# Lori King (ID: #38) received 'New York Teachers' Monographs' from Katherine Hem (ID: #207)
# Money (in €) involved in the transaction: 4.98 from Lori King to Katherine Hem (Payment Method: PayPal)
# Both books were on each other's wishlists.
#
# INFO: 'New York Teachers' Monographs':
# Author(s): Unknown, Publisher: Unknown, Date: 1909, ISBN: Unknown.
#
# INFO: 'Oxford University Gazette':
# Author(s): University of Oxford, Publisher: Unknown, Date: 1901, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Steven Degroat (ID: #235) rejected an exchange with Scott Bryant (ID: #142).
#
#        ----------------------------------------- Exchange #271 ----------------------------------------
# Kenneth Skursky (ID: #67) received 'Popular Science' from Cheryl Butterworth (ID: #285)
# Cheryl Butterworth (ID: #285) received 'Song Classics for High Voice [Vocal Scores with Piano Acc.]' from Kenneth Skursky (ID: #67)
# No money involved in the transaction.
# The books were not on each other's wishlists.
#
# INFO: 'Song Classics for High Voice [Vocal Scores with Piano Acc.]':
# Author(s): Unknown, Publisher: Unknown, Date: 1885, ISBN: Unknown.
#
# INFO: 'Popular Science':
# Author(s): Unknown, Publisher: Unknown, Date: 1940-08, ISBN: Unknown.
#        ----------------------------------------------------------------------------------------------
#
# Simulation completed!
#
#        ------------------------------------------ Metrics -------------------------------------------
#
# Users not involved in any exchange: 36 (12.0%)
# Rejected exchanges: 127
# Average number of owned books per user: 15.66
# Average number of books in the wishlist per user: 24.04
# Exchanges involving two books in each other's wishlist: 81 (29.89%)
# Exchanges in which one book was on a user's wishlist while the other not: 127 (46.86%)
# Exchanges in which none of the books is on each other's wishlists: 63 (23.25%)
# Exchanges involving a monetary transaction: 103 (38.01%)
# - Card: 18 (17.48%)
# - PayPal: 31 (30.1%)
# - ApplePay: 10 (9.71%)
# - GooglePay: 9 (8.74%)
# - SamsungPay: 14 (13.59%)
# - Cash: 21 (20.39%)
